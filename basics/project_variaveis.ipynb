# %% [markdown]
# ### Andriele Tatsch
#
# # Variables and Data Types
#
# ## Objective: Create variables and understand basic data types.

# %%
## Create variables of different data types

name = "Andriele" #string
age = 41          #integer
height = 1.63     #float
studying_python = True #boolean

#Printing all variables 
print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Studying Python:", studying_python)

# %%
# Challenge: Create a new variable with your favorite animal and print it

#pet information
pet_type = "dog"
breed = "australian shepherd"
name_pet = "Molly"
colors = "Black and white, details in Caramel"
numb_colors = 3
meals_day = 2
weight = 15.2
friendly = True 

#Printing all variables
print ("Pet type:", pet_type)
print("Breed:", breed)
print("Pet name:", name_pet)
print("Colors:", colors)
print("Number of Colors:", numb_colors)
print("Meals per day:", meals_day)
print("Weight:", weight)
print("Is friendly:", friendly)
